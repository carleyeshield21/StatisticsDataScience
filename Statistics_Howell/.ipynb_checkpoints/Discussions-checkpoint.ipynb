# %%
import statistics,math,numpy

list = [6,8,10]
mean = statistics.mean(list)
print(f'mean = {mean}')

list1 = [9,5,10]
mean1 = statistics.mean(list1)
print(f'list1 = {mean1}')
# Out:
# mean = 8
# list1 = 8

# %% [markdown]
# #### $\bullet$ Degrees of freedom
#
# In the lists above, the first one has a mean of 8, we use N-1 as the degree of freedom, because one element of the list cannot vary, it has to be dependent on the value of the original mean, we have change the first and third element to any value, but the second one has to adjust to a number so that if we take the mean, it has to be the same as the first list as 8.

# %%
new_inf = [2,1,7,1,33,2,2,3,4,3,4,3,3,10,9,2,5,4,3,3,20,6,2,4,5,2,1,3,3,4,2,3,4,3,2,3,2,4]
median = statistics.median(new_inf)
median
# Out:
# 3.0

# %%
import statistics,math,numpy
new_inf = [2,1,7,1,33,2,2,3,4,3,4,3,3,10,9,2,5,4,3,3,20,6,2,4,5,2,1,3,3,4,2,3,4,3,2,3,2,4]
corrected_new_inf = [2,1,7,1,3,2,2,3,4,3,4,3,3,10,9,2,5,4,3,3,5,6,2,4,5,2,1,3,3,4,2,3,4,3,2,3,2,4]
# Computing for quartiles using numpy
Q1 = numpy.percentile(new_inf,25)
Q2 = numpy.percentile(new_inf,50)
Q3 = numpy.percentile(new_inf,75)
print(f'Q1 = {Q1}\nQ2 = {Q2}\nQ3 = {Q3}')

# Inter Quartile Range (Q3-Q2)
IQR = Q3 - Q1
print(f'IQR = {IQR}')

# Creating a boxplot for the data
import matplotlib.pyplot as plt
plt.boxplot(new_inf)
plt.title('Newborn Infants')
plt.ylabel('Days of hospitalization')
# Out:
# Q1 = 2.0
# Q2 = 3.0
# Q3 = 4.0
# IQR = 2.0
# Text(0, 0.5, 'Days of hospitalization')

# %%
# Corrected data
plt.boxplot(corrected_new_inf)
plt.title('Newborn Infants')
plt.ylabel('Days of hospitalization')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data for boxplots
new_inf = [2,1,7,1,33,2,2,3,4,3,4,3,3,10,9,2,5,4,3,3,20,6,2,4,5,2,1,3,3,4,2,3,4,3,2,3,2,4]
corrected_new_inf = [2,1,7,1,3,2,2,3,4,3,4,3,3,10,9,2,5,4,3,3,5,6,2,4,5,2,1,3,3,4,2,3,4,3,2,3,2,4]

# Create a figure and subplots
# fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig, axes = plt.subplots(1, 2)

# Plot boxplots
axes[0].boxplot(new_inf)
axes[0].set_title('Boxplot 1')
axes[0].set_ylabel('Values')

axes[1].boxplot(corrected_new_inf)
axes[1].set_title('Boxplot 2')
axes[1].set_ylabel('Values')
plt.grid(True)
# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data for boxplots
new_inf = [2,1,7,1,33,2,2,3,4,3,4,3,3,10,9,2,5,4,3,3,20,6,2,4,5,2,1,3,3,4,2,3,4,3,2,3,2,4]
corrected_new_inf = [2,1,7,1,3,2,2,3,4,3,4,3,3,10,9,2,5,4,3,3,5,6,2,4,5,2,1,3,3,4,2,3,4,3,2,3,2,4]

# Combine data into a list
all_data = [new_inf, corrected_new_inf]

# Create a boxplot
# plt.figure(figsize=(10, 6))  # Set the figure size
plt.boxplot(all_data)

# Set labels and title
plt.xticks([1, 2], ['Data1', 'Data2'])  # Set x-axis labels
plt.ylabel('Values')  # Set y-axis label
plt.title('Multiple Boxplots')  # Set plot title

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# #### 2.1 Any of you who have listened to children tell stories will recognize that children differ from adults in that they tend to recall stories as a sequence of actions rather than as an overall plot. Their descriptions of a movie are filled with the phrase “and then. . . .” An experimenter with supreme patience asked 50 children to tell her about a given movie. Among other variables, she counted the number of “and then. . .” statements, which is the dependent variable. The data follow:
#
# then = [10, 11, 12, 15, 15, 15, 16, 16, 16, 16, 17, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 19, 19, 19, 19, 19, 19, 19, 20, 20, 20, 20, 20, 20, 20, 21, 21, 21, 22, 22, 23, 23, 24, 31, 40]
#
# a. Plot an ungrouped frequency distribution for these data.
#
# b. What is the general shape of the distribution?

# %%
import statistics,math,numpy
import matplotlib.pyplot as plt

then = [10, 11, 12, 15, 15, 15, 16, 16, 16, 16, 17, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 19, 19, 19, 19, 19, 19, 19, 20, 20, 20, 20, 20, 20, 20, 21, 21, 21, 22, 22, 23, 23, 24, 31, 40]
Q1 = numpy.percentile(then,25)
Q2 = numpy.percentile(then,50)
Q3 = numpy.percentile(then,75)
print(f'Q1 = {Q1}\nQ2 = {Q2}\nQ3 = {Q3}')
histo_then = plt.hist(then)
plt.show()
# Out:
# Q1 = 17.0
# Q2 = 18.0
# Q3 = 20.0

# %%
box_then = plt.boxplot(then)

# %% [markdown]
# #### 2.4As part of the study described in Exercise 2.1, the experimenter obtained the same kind of data for 50 adults. The data follow:
# data = [1, 3, 4, 5, 5, 7, 7, 7, 7, 8, 8, 8, 8, 9, 9, 9, 9, 9, 9, 9, 10, 10, 10, 10, 10, 10, 10, 10, 11, 11, 11, 11, 11, 11, 12, 12, 12, 12, 12, 13, 14, 14, 14, 14, 15, 15, 15, 16, 16, 17]

# %%
import statistics,math,numpy
import matplotlib.pyplot as plt

data = [1, 3, 4, 5, 5, 7, 7, 7, 7, 8, 8, 8, 8, 9, 9, 9, 9, 9, 9, 9, 10, 10, 10, 10, 10, 10, 10, 10, 11, 11, 11, 11, 11, 11, 12, 12, 12, 12, 12, 13, 14, 14, 14, 14, 15, 15, 15, 16, 16, 17]
Q1 = numpy.percentile(data,25)
Q2 = numpy.percentile(data,50)
Q3 = numpy.percentile(data,75)
print(f'Q1 = {Q1}\nQ2 = {Q2}\nQ3 = {Q3}')
histo_data = plt.hist(data)
plt.show()
# Out:
# Q1 = 8.25
# Q2 = 10.0
# Q3 = 12.0

# %%
box_plot_data = plt.boxplot(data)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for histograms
# data1 = np.random.normal(loc=0, scale=1, size=1000)
# data2 = np.random.normal(loc=2, scale=1, size=1000)
data1 = [10, 11, 12, 15, 15, 15, 16, 16, 16, 16, 17, 17, 17, 17, 17, 17, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 19, 19, 19, 19, 19, 19, 19, 20, 20, 20, 20, 20, 20, 20, 21, 21, 21, 22, 22, 23, 23, 24, 31, 40]
data2 = [1, 3, 4, 5, 5, 7, 7, 7, 7, 8, 8, 8, 8, 9, 9, 9, 9, 9, 9, 9, 10, 10, 10, 10, 10, 10, 10, 10, 11, 11, 11, 11, 11, 11, 12, 12, 12, 12, 12, 13, 14, 14, 14, 14, 15, 15, 15, 16, 16, 17]
# Plot histograms
plt.figure(figsize=(10, 6))  # Set the figure size
plt.hist(data1, bins=30, alpha=0.5, label='Data 1')  # Plot first histogram
plt.hist(data2, bins=30, alpha=0.5, label='Data 2')  # Plot second histogram

# Set labels and title
plt.xlabel('Values')  # Set x-axis label
plt.ylabel('Frequency')  # Set y-axis label
plt.title('Overlayed Histograms')  # Set plot title

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
