# %%
import pandas
import numpy

# %%
raw = pandas.read_csv('Family Income and Expenditure.csv')
raw
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 0                      480332                 CAR                  117848
# 1                      198235                 CAR                   67766
# 2                       82785                 CAR                   61609
# 3                      107589                 CAR                   78189
# 4                      189322                 CAR                   94625
# ...                       ...                 ...                     ...
# 41539                  119773  XII - SOCCSKSARGEN                   44875
# 41540                  137320  XII - SOCCSKSARGEN                   31157
# 41541                  133171  XII - SOCCSKSARGEN                   45882
# 41542                  129500  XII - SOCCSKSARGEN                   81416
# 41543                  128598  XII - SOCCSKSARGEN                   78195
#
#             Main Source of Income  Agricultural Household indicator  \
# ...

# %%
# Code to see all rows and columns
# pandas.options.display.max_columns = None
# pandas.options.display.max_rows = None

# %%
# Creating a copy of the data
data_copy = raw.copy()
data_copy
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 0                      480332                 CAR                  117848
# 1                      198235                 CAR                   67766
# 2                       82785                 CAR                   61609
# 3                      107589                 CAR                   78189
# 4                      189322                 CAR                   94625
# ...                       ...                 ...                     ...
# 41539                  119773  XII - SOCCSKSARGEN                   44875
# 41540                  137320  XII - SOCCSKSARGEN                   31157
# 41541                  133171  XII - SOCCSKSARGEN                   45882
# 41542                  129500  XII - SOCCSKSARGEN                   81416
# 41543                  128598  XII - SOCCSKSARGEN                   78195
#
#             Main Source of Income  Agricultural Household indicator  \
# ...

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41544 entries, 0 to 41543
# Data columns (total 60 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Total Household Income                         41544 non-null  int64
#  1   Region                                         41544 non-null  object
#  2   Total Food Expenditure                         41544 non-null  int64
#  3   Main Source of Income                          41544 non-null  object
#  4   Agricultural Household indicator               41544 non-null  int64
#  5   Bread and Cereals Expenditure                  41544 non-null  int64
#  6   Total Rice Expenditure                         41544 non-null  int64
#  7   Meat Expenditure                               41544 non-null  int64
#  8   Total Fish and  marine products Expenditure    41544 non-null  int64
# ...

# %%
agri_ind = pandas.get_dummies(data_copy['Agricultural Household indicator']).astype
agri_ind
# Out:
#            0      1      2
# 0       True  False  False
# 1       True  False  False
# 2      False   True  False
# 3       True  False  False
# 4       True  False  False
# ...      ...    ...    ...
# 41539  False   True  False
# 41540  False   True  False
# 41541  False  False   True
# 41542  False   True  False
# 41543  False   True  False
#
# [41544 rows x 3 columns]
