# %%
import numpy
import pandas
import statsmodels.api as sm
import matplotlib.pyplot
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression

# %%
raw_data = pandas.read_csv('1.04.+Real-life+example.csv')
raw_data.head()
# Out:
#            Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0            BMW   4200.0      sedan      277      2.0      Petrol
# 1  Mercedes-Benz   7900.0        van      427      2.9      Diesel
# 2  Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 3           Audi  23000.0  crossover      240      4.2      Petrol
# 4         Toyota  18300.0  crossover      120      2.0      Petrol
#
#   Registration  Year         Model
# 0          yes  1991           320
# 1          yes  1999  Sprinter 212
# 2          yes  2003         S 500
# 3          yes  2007            Q7
# 4          yes  2011         Rav 4

# %% [markdown]
# ## Pre-processing the data

# %% [markdown]
# ### Exploring the descriptive statistics of the variables

# %%
# raw_data.describe()
raw_data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# ...

# %% [markdown]
# ### Determining the variables of interest

# %%
# DataFrame.drop(columns,axis) returns new object with the indicated dropped, axis 0 means rows, axis 1 means columns
data = raw_data.drop(['Model'], axis=1)
data.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# ...

# %% [markdown]
# ### Dealing with missing values

# %%
data.isnull()
# Out:
#       Brand  Price   Body  Mileage  EngineV  Engine Type  Registration   Year
# 0     False  False  False    False    False        False         False  False
# 1     False  False  False    False    False        False         False  False
# 2     False  False  False    False    False        False         False  False
# 3     False  False  False    False    False        False         False  False
# 4     False  False  False    False    False        False         False  False
# ...     ...    ...    ...      ...      ...          ...           ...    ...
# 4340  False  False  False    False    False        False         False  False
# 4341  False  False  False    False    False        False         False  False
# 4342  False  False  False    False    False        False         False  False
# 4343  False  False  False    False     True        False         False  False
# 4344  False  False  False    False    False        False         False  False
#
# [4345 rows x 8 columns]

# %%
#Rule of thumb: if you are removing <5% of the observations, you are free to just remove it all that have missing values
data.isnull().sum() #shows the number of missing values in a row
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %% [markdown]
# ### Removing the missing values

# %%
data_no_missing_values = data.dropna(axis=0)
data_no_missing_values.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# ...

# %% [markdown]
# ### Exploring Probability Distribution Functions(PDFs)

# %%
sns.distplot(data_no_missing_values['Price'])
# Out:
# /tmp/ipykernel_30805/2137321590.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_missing_values['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# # DataFrame.quantile(the quantile) returns the value of the given quantile (=np.percentile)
# ### Dealing with outliers

# %%
q = data_no_missing_values['Price'].quantile(0.99)
data_1 = data_no_missing_values[data_no_missing_values['Price']<q]
# data_1.describe()
data_1.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3984    3984.000000   3984  3984.000000  3984.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1528          NaN          NaN
# mean           NaN   17837.117460    NaN   165.116466     2.743770
# std            NaN   18976.268315    NaN   102.766126     4.956057
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6980.000000    NaN    93.000000     1.800000
# 50%            NaN   11400.000000    NaN   160.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         3984         3984  3984.000000
# unique           4            2          NaN
# ...

# %%
sns.distplot(data_1['Price'])
# Out:
# /tmp/ipykernel_30805/2589761964.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(data_1['Mileage'])
# Out:
# /tmp/ipykernel_30805/1547815769.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
q = data_1['Mileage'].quantile(0.99)
data_2 = data_1[data_1['Mileage']<q]
sns.distplot(data_2['Mileage'])
# Out:
# /tmp/ipykernel_30805/2034858564.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
sns.distplot(data_1['EngineV'])
# Out:
# /tmp/ipykernel_30805/1659869432.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['EngineV'])
# <Axes: xlabel='EngineV', ylabel='Density'>

# %%
data_3 = data_2[data_2['EngineV']<6.5] #removing all values lower than 6.5
sns.distplot(data_3['EngineV'])
# Out:
# /tmp/ipykernel_30805/932928132.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3['EngineV'])
# <Axes: xlabel='EngineV', ylabel='Density'>

# %%
sns.distplot(data_no_missing_values['Year'])
# Out:
# /tmp/ipykernel_30805/477634043.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_missing_values['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
q = data_3['Year'].quantile(0.01)
q
# Out:
# 1987.0

# %%
data_4 = data_3[data_3['Year']>q]
sns.distplot(data_4['Year'])
# Out:
# /tmp/ipykernel_30805/1500453524.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_4['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
data_cleaned = data.reset_index(drop=True)
data_cleaned.describe(include='all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# ...

# %% [markdown]
# ### Checking OLS assumptions

# %%
f, (ax1, ax2, ax3) = matplotlib.pyplot.subplots(1,3, sharey=True, figsize=(15,3))
ax1.scatter(data_cleaned['Year'],data_cleaned['Price'])
ax1.set_title('Price and Year')

ax2.scatter(data_cleaned['EngineV'],data_cleaned['Price'])
ax2.set_title('Price and EngineV')

ax3.scatter(data_cleaned['Mileage'],data_cleaned['Price'])
ax3.set_title('Price and Mileage')

matplotlib.pyplot.show()

# %% [markdown]
# ### Relaxing the assumptions
# np.log(x) returns the natural logarithm of a number or array of numbers

# %%
log_price = numpy.log(data_cleaned['Price'])
data_cleaned['log_price'] = log_price #adding as a column
data_cleaned
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year  log_price
# 0             yes  1991   8.342840
# 1             yes  1999   8.974618
# ...

# %%
f, (ax1, ax2, ax3) = matplotlib.pyplot.subplots(1,3, sharey=True, figsize=(15,3))
ax1.scatter(data_cleaned['Year'],data_cleaned['log_price'])
ax1.set_title('Log Price and Year')

ax2.scatter(data_cleaned['EngineV'],data_cleaned['log_price'])
ax2.set_title('Log Price and EngineV')

ax3.scatter(data_cleaned['Mileage'],data_cleaned['log_price'])
ax3.set_title('Log Price and Mileage')

matplotlib.pyplot.show()

# %%
# data_cleaned = data_cleaned.drop(['Price'],axis=1)

# %%
data_cleaned.columns.values
# Out:
# array(['Brand', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'log_price'], dtype=object)

# %% [markdown]
# ### Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = data_cleaned[['Mileage','Year','EngineV']] #continuous variables
vif = pandas.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["features"] = variables.columns
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# Cell In[33], line 4
#       2 variables = data_cleaned[['Mileage','Year','EngineV']] #continuous variables
#       3 vif = pandas.DataFrame()
# ----> 4 vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
#       5 vif["features"] = variables.columns
#
# Cell In[33], line 4, in <listcomp>(.0)
#       2 variables = data_cleaned[['Mileage','Year','EngineV']] #continuous variables
#       3 vif = pandas.DataFrame()
# ----> 4 vif["VIF"] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
#       5 vif["features"] = variables.columns
#
# File /usr/local/lib64/python3.11/site-packages/statsmodels/stats/outliers_influence.py:197, in variance_inflation_factor(exog, exog_idx)
#     195 mask = np.arange(k_vars) != exog_idx
#     196 x_noti = exog[:, mask]
# ...

# %%
data_no_multicollinearity = data_cleaned.drop(['Year'],axis=1)
data_no_multicollinearity
# Out:
#               Brand       Body  Mileage  EngineV Engine Type Registration  \
# 0               BMW      sedan      277      2.0      Petrol          yes
# 1     Mercedes-Benz        van      427      2.9      Diesel          yes
# 2     Mercedes-Benz      sedan      358      5.0         Gas          yes
# 3              Audi  crossover      240      4.2      Petrol          yes
# 4            Toyota  crossover      120      2.0      Petrol          yes
# ...             ...        ...      ...      ...         ...          ...
# 4340  Mercedes-Benz      sedan        9      3.0      Diesel          yes
# 4341            BMW      sedan        1      3.5      Petrol          yes
# 4342            BMW      sedan      194      2.0      Petrol          yes
# 4343         Toyota      sedan       31      NaN      Petrol          yes
# 4344     Volkswagen        van      124      2.0      Diesel          yes
#
#       log_price
# 0      8.342840
# 1      8.974618
# 2      9.495519
# ...
